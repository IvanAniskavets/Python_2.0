# %%
pip3 install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\ivana\anaconda3\lib\site-packages (21.3.1)
# Collecting pip
#   Using cached pip-22.0.4-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.3.1
#     Uninstalling pip-21.3.1:
#       Successfully uninstalled pip-21.3.1
# Successfully installed pip-22.0.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ivana\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (1.39.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: setuptools in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ivana\appdata\roaming\python\python38\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: gast>=0.2.1 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\ivana\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\ivana\appdata\roaming\python\python38\site-packages (from tensorflow) (1.22.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ivana\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.36.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.25.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ivana\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.25.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ivana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ivana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ivana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ivana\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ivana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ivana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ivana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ivana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (4.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ivana\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ivana\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\ivana\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ivana\anaconda3\lib\site-packages)

# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.8.0
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('data_full/train_sample/*.jpg')
test_files = glob('data_full/test_sample/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
x = tf.keras.layers.Flatten()(x)
# TODO: add normalization
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.BatchNormalization()(x) # пакетная нормализация
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 33,326,913
# Trainable params: 25,691,137
# Non-trainable params: 7,635,776
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='rmsprop', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss)
              metrics=['accuracy'])

# %%
val_samples = 5  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 128s 13s/step - loss: 0.4889 - accuracy: 0.7469 - val_loss: 0.4979 - val_accuracy: 0.8000
# Epoch 2/100
# 10/10 [==============================] - 143s 14s/step - loss: 0.3535 - accuracy: 0.8375 - val_loss: 0.2872 - val_accuracy: 0.8000
# Epoch 3/100
# 10/10 [==============================] - 162s 16s/step - loss: 0.3099 - accuracy: 0.8594 - val_loss: 0.3908 - val_accuracy: 0.8000
# Epoch 4/100
# 10/10 [==============================] - 130s 13s/step - loss: 0.2793 - accuracy: 0.8813 - val_loss: 0.2883 - val_accuracy: 0.8000
# Epoch 5/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.3260 - accuracy: 0.8687 - val_loss: 1.2167 - val_accuracy: 0.6000
# Epoch 6/100
# 10/10 [==============================] - 114s 12s/step - loss: 0.2542 - accuracy: 0.8906 - val_loss: 0.3243 - val_accuracy: 0.8000
# Epoch 7/100
# 10/10 [==============================] - 115s 12s/step - loss: 0.2661 - accuracy: 0.8969 - val_loss: 0.0765 - val_accuracy: 1.0000
# Epoch 8/100
# 10/10 [==============================] - 114s 11s/step - loss: 0.2296 - accuracy: 0.9000 - val_loss: 0.1780 - val_accuracy: 1.0000
# Epoch 9/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.2303 - accuracy: 0.9000 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 10/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.2044 - accuracy: 0.9219 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 11/100
# 10/10 [==============================] - 105s 10s/step - loss: 0.2073 - accuracy: 0.9187 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 12/100
# 10/10 [==============================] - 106s 11s/step - loss: 0.2039 - accuracy: 0.9312 - val_loss: 0.1567 - val_accuracy: 1.0000
# Epoch 13/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.2209 - accuracy: 0.9219 - val_loss: 0.3500 - val_accuracy: 0.8000
# Epoch 14/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1835 - accuracy: 0.9250 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 15/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.2324 - accuracy: 0.8969 - val_loss: 0.1917 - val_accuracy: 0.8000
# Epoch 16/100
# 10/10 [==============================] - 105s 10s/step - loss: 0.1871 - accuracy: 0.9344 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 17/100
# 10/10 [==============================] - 111s 11s/step - loss: 0.1734 - accuracy: 0.9563 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 18/100
# 10/10 [==============================] - 130s 13s/step - loss: 0.2232 - accuracy: 0.9125 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 19/100
# 10/10 [==============================] - 127s 13s/step - loss: 0.2145 - accuracy: 0.9062 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 20/100
# 10/10 [==============================] - 130s 13s/step - loss: 0.1681 - accuracy: 0.9375 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 21/100
# 10/10 [==============================] - 127s 13s/step - loss: 0.1550 - accuracy: 0.9375 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1753 - accuracy: 0.9344 - val_loss: 0.0325 - val_accuracy: 1.0000
# Epoch 23/100
# 10/10 [==============================] - 106s 11s/step - loss: 0.1860 - accuracy: 0.9250 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 24/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.2014 - accuracy: 0.9281 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - 98s 10s/step - loss: 0.2281 - accuracy: 0.9125 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 26/100
# 10/10 [==============================] - 99s 10s/step - loss: 0.1429 - accuracy: 0.9531 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 27/100
# 10/10 [==============================] - 98s 10s/step - loss: 0.2165 - accuracy: 0.9156 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 28/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.1575 - accuracy: 0.9406 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 29/100
# 10/10 [==============================] - 106s 11s/step - loss: 0.1465 - accuracy: 0.9563 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 30/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.1633 - accuracy: 0.9250 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 31/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.1686 - accuracy: 0.9344 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 32/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.1644 - accuracy: 0.9281 - val_loss: 0.0608 - val_accuracy: 1.0000
# Epoch 33/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.2161 - accuracy: 0.9094 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 34/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.1913 - accuracy: 0.9281 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 35/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.1686 - accuracy: 0.9469 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 36/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.1253 - accuracy: 0.9500 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 37/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1832 - accuracy: 0.9375 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 38/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.1350 - accuracy: 0.9469 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 39/100
# 10/10 [==============================] - 99s 10s/step - loss: 0.1145 - accuracy: 0.9594 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - 98s 10s/step - loss: 0.2169 - accuracy: 0.9344 - val_loss: 0.0506 - val_accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.2100 - accuracy: 0.9281 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 42/100
# 10/10 [==============================] - 99s 10s/step - loss: 0.1848 - accuracy: 0.9344 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 43/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.1934 - accuracy: 0.9125 - val_loss: 0.0820 - val_accuracy: 1.0000
# Epoch 44/100
# 10/10 [==============================] - 99s 10s/step - loss: 0.1714 - accuracy: 0.9281 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 45/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.1293 - accuracy: 0.9406 - val_loss: 0.0536 - val_accuracy: 1.0000
# Epoch 46/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1600 - accuracy: 0.9375 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 47/100
# 10/10 [==============================] - 107s 11s/step - loss: 0.1497 - accuracy: 0.9500 - val_loss: 0.1482 - val_accuracy: 1.0000
# Epoch 48/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1578 - accuracy: 0.9406 - val_loss: 0.0783 - val_accuracy: 1.0000
# Epoch 49/100
# 10/10 [==============================] - 104s 11s/step - loss: 0.1286 - accuracy: 0.9563 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 50/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.1609 - accuracy: 0.9375 - val_loss: 0.1550 - val_accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1394 - accuracy: 0.9438 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 52/100
# 10/10 [==============================] - 107s 11s/step - loss: 0.0812 - accuracy: 0.9656 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 53/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1365 - accuracy: 0.9594 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 54/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0965 - accuracy: 0.9656 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - 108s 11s/step - loss: 0.1477 - accuracy: 0.9469 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 56/100
# 10/10 [==============================] - 98s 10s/step - loss: 0.1020 - accuracy: 0.9563 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 97s 10s/step - loss: 0.1724 - accuracy: 0.9312 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 97s 10s/step - loss: 0.1011 - accuracy: 0.9656 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 59/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.1427 - accuracy: 0.9469 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.1636 - accuracy: 0.9344 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 106s 11s/step - loss: 0.1545 - accuracy: 0.9406 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.1416 - accuracy: 0.9438 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.1507 - accuracy: 0.9469 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.1442 - accuracy: 0.9438 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 106s 11s/step - loss: 0.1984 - accuracy: 0.9250 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.1570 - accuracy: 0.9469 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 99s 10s/step - loss: 0.1149 - accuracy: 0.9563 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.1631 - accuracy: 0.9406 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.1890 - accuracy: 0.9250 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.1766 - accuracy: 0.9250 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.1113 - accuracy: 0.9531 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.1728 - accuracy: 0.9500 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 101s 10s/step - loss: 0.2101 - accuracy: 0.9187 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 100s 10s/step - loss: 0.1152 - accuracy: 0.9625 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 104s 11s/step - loss: 0.1501 - accuracy: 0.9344 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.1341 - accuracy: 0.9469 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.1797 - accuracy: 0.9375 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.1085 - accuracy: 0.9469 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0798 - accuracy: 0.9844 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 102s 10s/step - loss: 0.0735 - accuracy: 0.9812 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.0652 - accuracy: 0.9844 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0782 - accuracy: 0.9625 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0780 - accuracy: 0.9719 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 105s 11s/step - loss: 0.0702 - accuracy: 0.9875 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0919 - accuracy: 0.9656 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 105s 10s/step - loss: 0.0717 - accuracy: 0.9719 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 108s 11s/step - loss: 0.0626 - accuracy: 0.9812 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.0531 - accuracy: 0.9844 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 108s 11s/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.0620 - accuracy: 0.9812 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.1100 - accuracy: 0.9656 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 107s 11s/step - loss: 0.0653 - accuracy: 0.9750 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 107s 11s/step - loss: 0.0944 - accuracy: 0.9688 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.1049 - accuracy: 0.9531 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0691 - accuracy: 0.9812 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.0586 - accuracy: 0.9750 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.0972 - accuracy: 0.9781 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 104s 10s/step - loss: 0.0619 - accuracy: 0.9781 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 103s 10s/step - loss: 0.0931 - accuracy: 0.9625 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 106s 11s/step - loss: 0.0901 - accuracy: 0.9656 - val_loss: 0.0047 - val_accuracy: 1.0000

# %%
model.save('cats-dogs-vgg16_3.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit_3.csv', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))
