# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# %%
for dirname, _, filenames in os.walk('C:/Netology/CV_lectures_master/007/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# C:/Netology/CV_lectures_master/007/kaggle/input\fish-boxes\alb_labels.json
# C:/Netology/CV_lectures_master/007/kaggle/input\fish-boxes\bet_labels.json
# C:/Netology/CV_lectures_master/007/kaggle/input\fish-boxes\dol_labels.json
# C:/Netology/CV_lectures_master/007/kaggle/input\fish-boxes\lag_labels.json
# C:/Netology/CV_lectures_master/007/kaggle/input\fish-boxes\shark_labels.json
# C:/Netology/CV_lectures_master/007/kaggle/input\fish-boxes\yft_labels.json
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\sample_submission_stg1.csv
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\.DS_Store
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00003.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00010.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00012.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00015.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00019.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00020.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00029.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00032.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00037.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00038.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00039.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00041.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00043.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00045.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00055.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00057.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00074.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00085.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00090.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00097.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00110.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00121.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00130.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00134.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00136.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00154.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00156.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00163.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00177.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00186.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00187.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00188.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00191.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00193.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00197.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00201.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00206.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00208.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00209.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00211.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00215.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00219.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00227.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00228.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00233.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00236.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00237.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00239.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00248.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00264.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00269.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00270.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00274.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00275.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00277.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00278.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00281.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00288.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00290.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00291.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00294.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00295.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00296.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00299.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00300.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00301.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00317.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00319.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00327.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00337.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00338.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00341.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00342.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00344.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00351.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00353.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00356.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00361.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00366.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00369.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00381.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00384.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00385.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00396.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00401.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00403.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00415.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00421.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00425.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00447.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00451.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00457.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00461.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00466.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00482.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00490.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00496.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00502.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00507.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00508.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00509.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00523.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00525.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00526.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00544.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00545.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00546.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00555.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00558.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00561.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00562.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00568.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00570.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00576.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00579.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00592.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00594.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00595.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00596.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00605.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00607.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00617.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00624.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00626.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00632.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00633.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00634.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00636.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00638.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00643.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00653.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00660.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00665.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00668.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00672.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00679.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00684.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00687.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00690.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00701.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00705.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00706.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00710.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00712.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00713.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00714.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00715.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00719.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00722.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00727.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00728.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00741.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00742.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00744.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00745.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00747.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00754.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00756.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00762.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00782.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00788.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00790.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00793.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00809.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00810.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00811.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00817.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00820.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00823.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00824.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00829.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00831.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00834.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00840.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00843.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00863.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00866.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00869.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00870.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00878.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00880.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00881.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00885.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00893.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00895.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00897.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00898.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00899.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00901.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00911.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00928.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00939.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00940.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00956.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00957.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00961.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00967.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00970.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00975.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00984.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00987.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00993.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00994.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00996.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_00998.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01000.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01001.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01006.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01009.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01011.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01014.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01021.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01023.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01025.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01028.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01029.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01032.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01033.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01038.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01045.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01046.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01047.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01056.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01063.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01066.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01070.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01072.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01074.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01077.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01079.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01082.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01083.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01085.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01086.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01093.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01095.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01105.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01109.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01110.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01111.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01112.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01117.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01121.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01125.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01127.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01128.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01129.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01130.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01139.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01141.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01144.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01152.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01160.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01162.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01163.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01183.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01186.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01191.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01196.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01197.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01205.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01206.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01207.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01225.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01238.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01239.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01240.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01243.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01246.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01247.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01255.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01261.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01262.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01265.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01268.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01271.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01273.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01276.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01278.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01282.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01287.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01291.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01300.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01304.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01306.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01313.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01314.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01316.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01319.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01330.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01333.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01334.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01336.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01338.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01353.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01354.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01355.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01357.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01361.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01362.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01363.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01364.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01367.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01374.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01390.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01396.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01398.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01401.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01402.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01409.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01416.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01417.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01422.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01433.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01434.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01445.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01446.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01448.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01454.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01455.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01458.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01460.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01464.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01466.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01478.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01480.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01482.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01485.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01489.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01506.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01507.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01509.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01514.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01520.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01529.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01540.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01542.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01547.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01554.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01556.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01558.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01570.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01574.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01578.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01580.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01584.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01590.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01599.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01601.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01603.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01604.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01607.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01612.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01620.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01636.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01638.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01641.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01645.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01652.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01654.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01655.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01660.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01663.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01680.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01682.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01683.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01686.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01690.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01693.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01699.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01713.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01722.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01728.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01729.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01733.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01734.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01735.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01738.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01741.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01744.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01753.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01756.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01763.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01768.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01772.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01778.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01786.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01788.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01790.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01796.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01797.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01800.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01804.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01805.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01806.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01809.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01810.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01816.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01819.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01822.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01823.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01826.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01830.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01833.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01838.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01841.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\ALB\img_01846.jpg
# ...
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06550.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06567.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06569.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06576.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06586.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06592.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06593.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06599.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06600.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06625.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06635.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06650.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06660.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06666.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06672.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06687.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06724.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06729.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06754.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06763.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06765.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06769.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06771.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06782.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06805.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06819.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06822.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06824.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06835.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06841.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06846.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06854.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06858.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06875.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06897.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06898.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06919.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06920.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06925.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06971.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06980.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_06988.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07017.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07024.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07025.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07038.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07055.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07061.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07067.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07069.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07072.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07074.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07095.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07107.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07109.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07116.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07119.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07130.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07166.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07208.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07217.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07226.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07233.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07250.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07261.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07273.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07275.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07276.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07286.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07287.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07290.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07309.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07315.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07338.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07340.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07341.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07344.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07368.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07369.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07383.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07388.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07395.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07400.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07403.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07427.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07429.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07431.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07462.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07466.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07472.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07499.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07510.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07513.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07517.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07530.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07535.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07541.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07555.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07562.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07569.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07571.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07577.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07588.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07595.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07602.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07609.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07610.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07613.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07624.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07633.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07644.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07648.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07649.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07653.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07655.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07665.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07706.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07712.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07714.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07731.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07742.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07747.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07750.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07752.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07759.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07761.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07765.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07775.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07782.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07828.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07849.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07852.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07853.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07854.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07891.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07901.jpg
# C:/Netology/CV_lectures_master/007/kaggle/input\the-nature-conservancy-fisheries-monitoring\train\YFT\img_07911.jpg

# %%
# %matplotlib inline
import cv2
import random
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# # Загружаем разметку

# %%
import os
import json
from glob import glob

# TODO: скачайте данные и сохраните в директорию:
TRAIN_PREFIX = 'C:/Netology/CV_lectures_master/007/kaggle/input/the-nature-conservancy-fisheries-monitoring/train'

def load_boxes():
    boxes = dict()
    for path in glob('C:/Netology/CV_lectures_master/007/kaggle/input/fish-boxes/*.json'):
        label = os.path.basename(path).split('_', 1)[0]
        with open(path) as src:
            boxes[label] = json.load(src)
            for annotation in boxes[label]:
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = os.path.join(TRAIN_PREFIX, label.upper(), basename)
                annotation['class'] = os.path.split(os.path.dirname(annotation['filename']))[1]
            for annotation in boxes[label]:
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for rect in rectangles:
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=4)
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation['annotations'], scale_x, scale_y)
    
    if rectangles is not None:
        img = _draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %% [markdown]
# ### Визуализируем разметку

# %%
boxes = load_boxes()  # разметка детекций

# %%
pd.DataFrame([(k, len(v)) for k, v in boxes.items()],
             columns=['class', 'count'])
# Out:
#    class  count
# 0    alb   1719
# 1    bet    200
# 2    dol    117
# 3    lag     67
# 4  shark    176
# 5    yft    734

# %%
labels = sorted(list(map(str.upper, list(boxes.keys()))) + ['NoF','OTHER'])
print(labels)
print([int(i == 'SHARK') for i in labels], type([int(i == 'SHARK') for i in labels]))
# Out:
# ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
# [0, 0, 0, 0, 0, 0, 1, 0] <class 'list'>

# %%
plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(boxes['lag'][17])
plt.imshow(img)
plt.title('{}x{}'.format(*img.shape));

# %% [markdown]
# ### Распределение размеров разметки

# %%
annotations = sum([box['annotations']
                  for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %% [markdown]
# # Экстрактор признаков

# %%
IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = keras.applications.vgg16.VGG16(include_top=False,
                                          weights='imagenet',
                                          input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

feature_tensor = features.layers[-1].output

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False

# %%
feature_tensor.shape
# Out:
# TensorShape([None, 23, 37, 512])

# %% [markdown]
# # Сетка якорей (anchor grid)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1],
                 feature_tensor.shape[2])

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 5+8), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    #print(annotation)
    y = annotation['class']
    for rect in annotation['annotations']:
        scores = []
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]
        #print(y, labels, [int(i == y) for i in labels])
        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = [1., dx, dy, dw, dh] + [int(i == y) for i in labels]
            
    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            logit, dx, dy, dw, dh = prediction[row, col][:5]
            conf = _sigmoid(logit)
            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf})
    return rectangles

# %% [markdown]
# ### Валидация энкодинга/декодинга якорей

# %%
example = boxes['alb'][175]
#print(example)
encoded = encode_anchors(example, (IMG_HEIGHT, IMG_WIDTH))
#print(encoded)
decoded = decode_prediction(encoded, conf_thr=0.5)
decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(example, decoded[:10]))

# %% [markdown]
# ## Функция потерь

# %%
K = tf.keras.backend

def confidence_loss(y_true, y_pred):
    conf_loss = K.binary_crossentropy(y_true[..., 0], 
                                      y_pred[..., 0],
                                      from_logits=True)
    return conf_loss

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., 1:] - y_pred[..., 1:])
    square_loss = 0.5 * K.square(y_true[..., 1:] - y_pred[..., 1:])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)

def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    # TODO: добавьте функцию потерь для классификации детекции
    
    y_true = K.reshape(y_true, (batch_size, -1, 5))
    y_pred = K.reshape(y_pred, (batch_size, -1, 5))

    # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)
    
    # positive examples loss
    pos_conf_loss = K.sum(conf_loss * y_true[..., 0], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., 0], axis=-1)
    
    # negative examples loss
    anchors = K.shape(y_true)[1]
    num_pos = K.sum(y_true[..., 0], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., 0]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
    
    return total_conf_loss + 0.5 * loc_loss

# %% [markdown]
# ## Загрузка данных

# %%
def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    return img_shape, keras.applications.vgg16.preprocess_input(img_resized.astype(np.float32))

def data_generator(boxes, batch_size=32):
    boxes = sum(boxes.values(), [])
    while True:
        random.shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                # TODO: добавьте one-hot encoding в разметку для классов
                #print(encode_anchors(boxes[j], img_shape))
                #print(boxes[j]['class'])
                y.append([int(boxes[j]['class']==c) for c in labels]) #encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

# %% [markdown]
# ## Добавляем выход детектора

# %%
output = keras.layers.BatchNormalization()(feature_tensor)

# TODO: добавьте выходы для классификации детекции
#output = keras.layers.Conv2D(5, kernel_size=(1, 1), activation='linear', kernel_regularizer='l2')(output)

output = keras.layers.Flatten()(output)

output = keras.layers.Dense(64, activation='relu')(output)
output = keras.layers.Dropout(0.5)(output)
output = keras.layers.BatchNormalization()(output)
output = keras.layers.Dense(8, activation='softmax')(output)

model = keras.models.Model(inputs=features.inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 750, 1200, 3)]    0
#
#  block1_conv1 (Conv2D)       (None, 750, 1200, 64)     1792
#
#  block1_conv2 (Conv2D)       (None, 750, 1200, 64)     36928
#
#  block1_pool (MaxPooling2D)  (None, 375, 600, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 375, 600, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 375, 600, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 187, 300, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 187, 300, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 93, 150, 256)      0
#
#  block4_conv1 (Conv2D)       (None, 93, 150, 512)      1180160
#
#  block4_conv2 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_conv3 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_pool (MaxPooling2D)  (None, 46, 75, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 23, 37, 512)       0
#
#  batch_normalization (BatchN  (None, 23, 37, 512)      2048
#  ormalization)
#
#  flatten (Flatten)           (None, 435712)            0
#
#  dense (Dense)               (None, 64)                27885632
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_1 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 42,603,144
# Trainable params: 34,966,728
# Non-trainable params: 7,636,416
# _________________________________________________________________

# %% [markdown]
# ## Learn

# %%
adam = keras.optimizers.Adam(learning_rate=3e-4, decay=1e-6)
#model.compile(optimizer=adam, loss=total_loss, metrics={'conf_loss': confidence_loss})
#model.compile(loss='sparse_categorical_crossentropy', optimizer=adam)#, metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer=adam)
#, metrics=['accuracy']

#sgd = SGD(lr=0.01, momentum=0.9, decay=0.0005, nesterov=False)
#model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
int(sum(map(len, boxes.values()), 0))
# Out:
# 3013

# %%
batch_size = 5
steps_per_epoch = int(sum(map(len, boxes.values()), 0) / batch_size)

gen = data_generator(boxes, batch_size=batch_size)

checkpoint = keras.callbacks.ModelCheckpoint(
    'weights.{epoch:02d}-{loss:.3f}.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=False,
    mode='auto', save_freq=10)

model.fit(gen, steps_per_epoch=steps_per_epoch, epochs=25, callbacks=[checkpoint])
model.save('model.hdf5')
# Out:
# Epoch 1/25
#   9/602 [..............................] - ETA: 6:15:07 - loss: 2.6404
# Epoch 1: loss improved from inf to 2.57115, saving model to weights.01-2.571.hdf5
#  19/602 [..............................] - ETA: 5:42:24 - loss: 2.5654
# Epoch 1: loss improved from 2.57115 to 2.56805, saving model to weights.01-2.568.hdf5
#  29/602 [>.............................] - ETA: 5:25:48 - loss: 2.5965
# Epoch 1: loss did not improve from 2.56805
#  39/602 [>.............................] - ETA: 5:16:30 - loss: 2.5818
# Epoch 1: loss did not improve from 2.56805
#  49/602 [=>............................] - ETA: 5:09:08 - loss: 2.6245
# Epoch 1: loss did not improve from 2.56805
#  59/602 [=>............................] - ETA: 5:03:47 - loss: 2.5974
# Epoch 1: loss did not improve from 2.56805
#  69/602 [==>...........................] - ETA: 4:58:36 - loss: 2.5770
# Epoch 1: loss did not improve from 2.56805
#  79/602 [==>...........................] - ETA: 4:53:16 - loss: 2.5417
# Epoch 1: loss improved from 2.56805 to 2.53780, saving model to weights.01-2.538.hdf5
#  89/602 [===>..........................] - ETA: 4:46:02 - loss: 2.5150
# Epoch 1: loss improved from 2.53780 to 2.50960, saving model to weights.01-2.510.hdf5
#  99/602 [===>..........................] - ETA: 4:40:47 - loss: 2.4688
# Epoch 1: loss improved from 2.50960 to 2.46635, saving model to weights.01-2.466.hdf5
# 109/602 [====>.........................] - ETA: 4:37:42 - loss: 2.4393
# Epoch 1: loss improved from 2.46635 to 2.43026, saving model to weights.01-2.430.hdf5
# 119/602 [====>.........................] - ETA: 4:36:04 - loss: 2.4072
# Epoch 1: loss improved from 2.43026 to 2.40651, saving model to weights.01-2.407.hdf5
# 129/602 [=====>........................] - ETA: 4:33:21 - loss: 2.3867
# Epoch 1: loss improved from 2.40651 to 2.38725, saving model to weights.01-2.387.hdf5
# 139/602 [=====>........................] - ETA: 4:30:23 - loss: 2.3885
# Epoch 1: loss improved from 2.38725 to 2.38681, saving model to weights.01-2.387.hdf5
# 149/602 [======>.......................] - ETA: 4:26:47 - loss: 2.3617
# Epoch 1: loss improved from 2.38681 to 2.36084, saving model to weights.01-2.361.hdf5
# 159/602 [======>.......................] - ETA: 4:21:17 - loss: 2.3365
# Epoch 1: loss improved from 2.36084 to 2.33082, saving model to weights.01-2.331.hdf5
# 169/602 [=======>......................] - ETA: 4:14:55 - loss: 2.3163
# Epoch 1: loss improved from 2.33082 to 2.31659, saving model to weights.01-2.317.hdf5
# 179/602 [=======>......................] - ETA: 4:09:18 - loss: 2.2852
# Epoch 1: loss improved from 2.31659 to 2.27966, saving model to weights.01-2.280.hdf5
# 189/602 [========>.....................] - ETA: 4:03:09 - loss: 2.2615
# Epoch 1: loss improved from 2.27966 to 2.25785, saving model to weights.01-2.258.hdf5
# 199/602 [========>.....................] - ETA: 3:57:18 - loss: 2.2462
# Epoch 1: loss improved from 2.25785 to 2.24456, saving model to weights.01-2.245.hdf5
# 209/602 [=========>....................] - ETA: 3:51:46 - loss: 2.2328
# Epoch 1: loss improved from 2.24456 to 2.23283, saving model to weights.01-2.233.hdf5
# 219/602 [=========>....................] - ETA: 3:45:51 - loss: 2.2070
# Epoch 1: loss improved from 2.23283 to 2.20490, saving model to weights.01-2.205.hdf5
# 229/602 [==========>...................] - ETA: 3:39:52 - loss: 2.1985
# Epoch 1: loss improved from 2.20490 to 2.19442, saving model to weights.01-2.194.hdf5
# 239/602 [==========>...................] - ETA: 3:33:27 - loss: 2.1887
# Epoch 1: loss improved from 2.19442 to 2.18550, saving model to weights.01-2.186.hdf5
# 249/602 [===========>..................] - ETA: 3:28:19 - loss: 2.1765
# Epoch 1: loss improved from 2.18550 to 2.17471, saving model to weights.01-2.175.hdf5
# 259/602 [===========>..................] - ETA: 3:22:28 - loss: 2.1645
# Epoch 1: loss improved from 2.17471 to 2.16455, saving model to weights.01-2.165.hdf5
# 269/602 [============>.................] - ETA: 3:16:39 - loss: 2.1618
# Epoch 1: loss improved from 2.16455 to 2.15914, saving model to weights.01-2.159.hdf5
# 279/602 [============>.................] - ETA: 3:10:36 - loss: 2.1500
# Epoch 1: loss improved from 2.15914 to 2.14862, saving model to weights.01-2.149.hdf5
# 289/602 [=============>................] - ETA: 3:04:35 - loss: 2.1347
# Epoch 1: loss improved from 2.14862 to 2.13428, saving model to weights.01-2.134.hdf5
# 299/602 [=============>................] - ETA: 2:59:02 - loss: 2.1305
# Epoch 1: loss improved from 2.13428 to 2.13095, saving model to weights.01-2.131.hdf5
# 309/602 [==============>...............] - ETA: 2:53:16 - loss: 2.1193
# Epoch 1: loss improved from 2.13095 to 2.11786, saving model to weights.01-2.118.hdf5
# 319/602 [==============>...............] - ETA: 2:47:34 - loss: 2.1114
# Epoch 1: loss improved from 2.11786 to 2.10993, saving model to weights.01-2.110.hdf5
# 329/602 [===============>..............] - ETA: 2:42:20 - loss: 2.0994
# Epoch 1: loss improved from 2.10993 to 2.09741, saving model to weights.01-2.097.hdf5
# 339/602 [===============>..............] - ETA: 2:37:15 - loss: 2.0848
# Epoch 1: loss improved from 2.09741 to 2.08342, saving model to weights.01-2.083.hdf5
# 349/602 [================>.............] - ETA: 2:31:25 - loss: 2.0780
# Epoch 1: loss improved from 2.08342 to 2.08022, saving model to weights.01-2.080.hdf5
# 359/602 [================>.............] - ETA: 2:25:29 - loss: 2.0706
# Epoch 1: loss improved from 2.08022 to 2.06912, saving model to weights.01-2.069.hdf5
# 369/602 [=================>............] - ETA: 2:19:40 - loss: 2.0582
# Epoch 1: loss improved from 2.06912 to 2.05644, saving model to weights.01-2.056.hdf5
# 379/602 [=================>............] - ETA: 2:14:49 - loss: 2.0489
# Epoch 1: loss improved from 2.05644 to 2.04809, saving model to weights.01-2.048.hdf5
# 389/602 [==================>...........] - ETA: 2:09:13 - loss: 2.0382
# Epoch 1: loss improved from 2.04809 to 2.03737, saving model to weights.01-2.037.hdf5
# 399/602 [==================>...........] - ETA: 2:03:19 - loss: 2.0336
# Epoch 1: loss improved from 2.03737 to 2.03378, saving model to weights.01-2.034.hdf5
# 409/602 [===================>..........] - ETA: 1:57:27 - loss: 2.0324
# Epoch 1: loss improved from 2.03378 to 2.03217, saving model to weights.01-2.032.hdf5
# 419/602 [===================>..........] - ETA: 1:51:34 - loss: 2.0223
# Epoch 1: loss improved from 2.03217 to 2.02223, saving model to weights.01-2.022.hdf5
# 429/602 [====================>.........] - ETA: 1:45:40 - loss: 2.0141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-728a27784cdf> in <module>
#      12     mode='auto', save_freq=10)
#      13
# ---> 14 model.fit(gen, steps_per_epoch=steps_per_epoch, epochs=25, callbacks=[checkpoint])
#      15 model.save('model.hdf5')
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#model.load_weights('weights.03-0.086.hdf5')
#model = keras.models.load_model('C:/Netology/CV_lectures_master/007/kaggle/input/models/model.hdf5')

# %% [markdown]
# ## Результат работы детектора

# %%
example = boxes['lag'][0]

img_shape, sample_img = load_img('## Результат работы детектораtest_stg1/img_02811.jpg') #example['filename'])
pred = model.predict(np.array([sample_img,]))[0]

# %%
img_shape, ['lag00']+list(pred)
# Out:
# ((720, 1280, 3),
#  ['lag00',
#   array([0.04316749, 0.13635738, 0.43120533, 0.01614819, 0.03946834,
#          0.07995746, 0.06285077, 0.19084503], dtype=float32)])

# %%
pred[0][0]
# Out:
# 0.043167487

# %%
annotation = boxes['lag'][0]

_, sample_img = load_img(annotation['filename'])
pred = model.predict(np.array([sample_img,]))

decoded = decode_prediction(pred[0], conf_thr=0.2)
decoded = non_max_suppression(decoded,
                              max_output_size=5,
                              iou_threshold=0.1)

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(annotation, decoded, (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('Предсказание модели {}x{}'.format(*img.shape));
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-b16889b36816> in <module>
#       4 pred = model.predict(np.array([sample_img,]))
#       5
# ----> 6 decoded = decode_prediction(pred[0], conf_thr=0.2)
#       7 decoded = non_max_suppression(decoded,
#       8                               max_output_size=5,
#
# <ipython-input-13-f7fd5057f642> in decode_prediction(prediction, conf_thr)
#      60     for row in range(FEATURE_SHAPE[0]):
#      61         for col in range(FEATURE_SHAPE[1]):
# ---> 62             logit, dx, dy, dw, dh = prediction[row, col][:5]
#      63             conf = _sigmoid(logit)
#      64             if conf > conf_thr:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# ## Визуализируем предсказание на тесте

# %%
test_images = glob('C:/Netology/CV_lectures_master/007/kaggle/input/the-nature-conservancy-fisheries-monitoring/test_stg1/*.jpg')[:5]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename)
    pred = model.predict(np.array([sample_img,]))

    decoded = decode_prediction(pred[0], conf_thr=0.0)
    decoded = non_max_suppression(decoded,
                                  max_output_size=2,
                                  iou_threshold=0.1)
    
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes({'filename': filename}, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание на тесте {}'.format(filename));
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-0b1571e50719> in <module>
#       8     pred = model.predict(np.array([sample_img,]))
#       9
# ---> 10     decoded = decode_prediction(pred[0], conf_thr=0.0)
#      11     decoded = non_max_suppression(decoded,
#      12                                   max_output_size=2,
#
# <ipython-input-13-f7fd5057f642> in decode_prediction(prediction, conf_thr)
#      60     for row in range(FEATURE_SHAPE[0]):
#      61         for col in range(FEATURE_SHAPE[1]):
# ---> 62             logit, dx, dy, dw, dh = prediction[row, col][:5]
#      63             conf = _sigmoid(logit)
#      64             if conf > conf_thr:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# ## Агрегация результатов

# %%
# TODO: предскажите класс рыбы для фотографии из тестовой выборки
#
# Подготовьте файл с предсказаниями вероятностей для каждой фотографии:
# image,ALB,BET,DOL,LAG,NoF,OTHER,SHARK,YFT
# img_00001.jpg,1,0,0,0,0,...,0
# img_00002.jpg,0.3,0.1,0.6,0,...,0
import csv
TEST_PREFIX = 'C:/Netology/CV_lectures_master/007/kaggle/input/the-nature-conservancy-fisheries-monitoring/test_stg1/'
TEST_PREFIX2 = 'C:/Netology/CV_lectures_master/007/kaggle/input/the-nature-conservancy-fisheries-monitoring-stage2/test_stg2/'

with open("submission.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(['image'] + labels)
    for im in os.listdir(TEST_PREFIX):
        _, img = load_img(os.path.join(TEST_PREFIX,im))
        writer.writerow([im] + list(model.predict(np.array([img,]), verbose=1)[0]))
    for im in os.listdir(TEST_PREFIX2):
        _, img = load_img(os.path.join(TEST_PREFIX2,im))
        writer.writerow(['test_stg2/'+im] + list(model.predict(np.array([img,]), verbose=1)[0]))
